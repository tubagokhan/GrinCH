# %% [markdown]
# <a href="https://colab.research.google.com/github/tubagokhan/GrinCH/blob/main/GraphInClusterPubMedTextRank_all_distilroberta_v1-2700-3000.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install transformers
# !pip install datasets
# !pip install torch
# !pip install scikit-learn
# !pip install matplotlib
# !pip install sentence_transformers
# !pip install py-rouge==1.1
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.35.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.11.17)
# Collecting datasets
#   Downloading datasets-2.16.1-py3-none-any.whl (507 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 507.1/507.1 kB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.13.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.23.5)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (10.0.1)
# Collecting pyarrow-hotfix (from datasets)
#   Downloading pyarrow_hotfix-0.6-py3-none-any.whl (7.9 kB)
# Collecting dill<0.3.8,>=0.3.0 (from datasets)
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 13.6 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.4.1)
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.15-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 16.1 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2023.10.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.1)
# Requirement already satisfied: huggingface-hub>=0.19.4 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.20.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.4->datasets) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2023.11.17)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Installing collected packages: pyarrow-hotfix, dill, multiprocess, datasets
# Successfully installed datasets-2.16.1 dill-0.3.7 multiprocess-0.70.15 pyarrow-hotfix-0.6
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.1.0+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.23.5)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.2.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Collecting sentence_transformers
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 1.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (4.35.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (4.66.1)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (2.1.0+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (0.16.0+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.23.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.11.4)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (3.8.1)
# Collecting sentencepiece (from sentence_transformers)
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 9.0 MB/s eta 0:00:00
# Requirement already satisfied: huggingface-hub>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (0.20.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (23.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence_transformers) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence_transformers) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence_transformers) (3.1.2)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence_transformers) (2.1.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (2023.6.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (0.4.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->sentence_transformers) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->sentence_transformers) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence_transformers) (3.2.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->sentence_transformers) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6.0->sentence_transformers) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->sentence_transformers) (1.3.0)
# Building wheels for collected packages: sentence_transformers
#   Building wheel for sentence_transformers (setup.py) ... done
#   Created wheel for sentence_transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125923 sha256=a28b28675b4afc00237f42a1f526110e59d47df912fe08e03158dcac97cd3455
#   Stored in directory: /root/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
# Successfully built sentence_transformers
# Installing collected packages: sentencepiece, sentence_transformers
# Successfully installed sentence_transformers-2.2.2 sentencepiece-0.1.99
# Collecting py-rouge==1.1
#   Downloading py_rouge-1.1-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.8/56.8 kB 836.7 kB/s eta 0:00:00
# Installing collected packages: py-rouge
# Successfully installed py-rouge-1.1

# %%
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sentence_transformers import SentenceTransformer
from nltk import sent_tokenize,word_tokenize

from sklearn.metrics.pairwise import cosine_similarity
import networkx as nx

import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')

import warnings
warnings.filterwarnings("ignore")
import re

from datasets import load_dataset
from scipy.spatial import distance

import math
from math import*

import rouge

import networkx as nx

import time
from transformers import logging
logging.set_verbosity_error()

import json
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.

# %%
# Preprocessing method
def preprocess_corpus(text):
    # Remove special characters and extra whitespaces
    text = re.sub(r"[^a-zA-Z0-9\s.]", "", text)
    text = re.sub(r"\s+", " ", text)
    return text

def textSentenceCount(Text):
    number_of_sentences = sent_tokenize(Text)
    count=(len(number_of_sentences))
    return count

def cosine(u, v):
    return np.dot(u, v) / (np.linalg.norm(u) * np.linalg.norm(v))

def createSummaryUsingKMeans(corpus, modelName):
    sentences = sent_tokenize(corpus)
    model = SentenceTransformer(modelName)
    sentence_embeddings = model.encode(sentences)

    optimum_clusters = find_optimum_clusters(sentence_embeddings, int(len(sentences) / 3))
    print("Optimum cluster number:", optimum_clusters)

    # Perform kmean clustering
    kmeans = KMeans(n_clusters=optimum_clusters, random_state=0, n_init='auto').fit(sentence_embeddings)

    chosen_sentence_indexes=[]
    cluster_rank=[]
    for cluster_id in range(optimum_clusters):
        cluster_indices = np.where(kmeans.labels_ == cluster_id)[0]
        cluster_weight=clusterWeight(sentence_embeddings, cluster_indices)
        cluster_rank.append(cluster_weight)
        chosen_sentence_index=text_rank(sentence_embeddings, cluster_indices)
        chosen_sentence_indexes.append(chosen_sentence_index)

    if optimum_clusters>10:
      choosen_clusters=k_highest_indices(cluster_rank, 10)
      chosen_sentence_indexes = [chosen_sentence_indexes[i] for i in choosen_clusters]

    sorted_indexes=sorted(chosen_sentence_indexes)

    chosen_sentences = []
    for chosen_sentence_index in sorted_indexes:
        chosen_sentences.append(sentences[chosen_sentence_index])

    summary = " ".join(chosen_sentences)

    return summary

#function calculates the optimal number of clusters using the elbow method. The function plots the elbow curve, which shows the inertia values for different cluster numbers. The user can visually inspect the plot to determine the elbow point, indicating the optimal number of clusters.
def find_optimum_clusters(data, max_clusters):
    inertias = []
    for k in range(1, max_clusters + 1):
        kmeans = KMeans(n_clusters=k, random_state=0).fit(data)
        inertias.append(kmeans.inertia_)

    # Plotting the elbow curve
    #plt.plot(range(1, max_clusters + 1), inertias)
    #plt.xlabel("Number of Clusters")
    #plt.ylabel("Inertia")
    #plt.title("Elbow Curve")
    #plt.show()

    # Calculate the optimal number of clusters using the elbow method
    diff = np.diff(inertias)
    acceleration = np.diff(diff)
    opt_cluster_num = acceleration.argmin() + 2  # Adding 2 to get the index of the minimum acceleration
    return opt_cluster_num

def clusterWeight(sentence_embeddings, cluster_indices):
  length=len(cluster_indices)
  sentenceGraph =np.zeros((length, length))
  for x in range(length):
    for y in range(length):
      if x>y:
        similarity= cosine(sentence_embeddings[cluster_indices[x]],sentence_embeddings[cluster_indices[y]])
        sentenceGraph[x][y]=abs(similarity)
    #print(sentenceGraph)
  SumElement=(np.concatenate(sentenceGraph).sum())
  return round(SumElement,2)

def k_highest_indices(cluster_weight_list, k):
    # Enumerate the list to keep track of original indices
    enumerated_list = list(enumerate(cluster_weight_list))

    # Sort the enumerated list in descending order based on the float values
    sorted_list = sorted(enumerated_list, key=lambda x: x[1], reverse=True)

    # Extract the indices of the k highest elements
    k_highest_indices = [item[0] for item in sorted_list[:k]]

    return k_highest_indices

def text_rank(sentence_embeddings, indexes):
    # Filter embeddings based on the input indexes
    filtered_embeddings = np.array([sentence_embeddings[i] for i in indexes])

    # Calculate cosine similarity between filtered sentence embeddings
    similarity_matrix = cosine_similarity(filtered_embeddings, filtered_embeddings)

    # Create a graph using similarity matrix
    graph = nx.from_numpy_array(similarity_matrix)
    try:
      # Apply TextRank algorithm to rank the sentences
      scores = nx.pagerank(graph, max_iter=1000)
          # Get the index of the highest-ranked sentence
      highest_ranked_index = max(scores, key=scores.get)

      # Get the original index from the list of indexes
      highest_ranked_original_index = indexes[highest_ranked_index]
      return highest_ranked_original_index
    except:
      print("######### Error with PageRank")
      return indexes[0]

# %%
#modelName = 'all-mpnet-base-v2'
modelName ='all-distilroberta-v1'
dataset = load_dataset("scientific_papers", "pubmed")

startTimeforOverall = time.time()
all_summary = []
all_goldstandart = []

N = 300
startN = 2700

for d in range(N):
    startTimeforDocument = time.time()
    print("Document:", startN + d + 1)
    corpus = dataset['test']['article'][startN + d]
    corpus = preprocess_corpus(corpus)
    print("Document sentence number:", textSentenceCount(corpus))


    if textSentenceCount(corpus) > 8:
        summary = createSummaryUsingKMeans(corpus, modelName)
        print("Summary sentence number:", textSentenceCount(summary))
        all_summary.append(summary)
    else:
      all_summary.append(corpus)
      print("Corpus is less than 9 sentence, summarization didn't apply sentence number:", textSentenceCount(corpus))

    all_goldstandart.append(dataset['test']['abstract'][startN + d])
    elapsedTimeforDocument = time.time() - startTimeforDocument
    elapsedTimeforAll = time.time() - startTimeforOverall
    print('Document processing time: '+time.strftime("%M:%S", time.gmtime(elapsedTimeforDocument)))
    print('Total processing time: '+time.strftime("%d:%H:%M:%S", time.gmtime(elapsedTimeforAll)))

    print("----------------------------------")
# Out:
# Downloading builder script:   0%|          | 0.00/5.35k [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/4.99k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/8.27k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/3.62G [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/880M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/119924 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/6633 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/6658 [00:00<?, ? examples/s]
# Document: 2701
# Document sentence number: 366
# .gitattributes:   0%|          | 0.00/737 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.3k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/653 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# data_config.json:   0%|          | 0.00/15.7k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/329M [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/333 [00:00<?, ?B/s]
# train_script.py:   0%|          | 0.00/13.1k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# Optimum cluster number: 30
# Summary sentence number: 10
# Document processing time: 03:20
# Total processing time: 01:00:03:20
# ----------------------------------
# Document: 2702
# Document sentence number: 188
# Optimum cluster number: 14
# Summary sentence number: 10
# Document processing time: 01:01
# Total processing time: 01:00:04:21
# ----------------------------------
# Document: 2703
# Document sentence number: 113
# Optimum cluster number: 25
# Summary sentence number: 10
# Document processing time: 00:29
# Total processing time: 01:00:04:51
# ----------------------------------
# Document: 2704
# Document sentence number: 61
# Optimum cluster number: 8
# Summary sentence number: 8
# Document processing time: 00:07
# Total processing time: 01:00:04:58
# ----------------------------------
# Document: 2705
# Document sentence number: 210
# Optimum cluster number: 23
# Summary sentence number: 10
# Document processing time: 01:13
# Total processing time: 01:00:06:12
# ----------------------------------
# Document: 2706
# Document sentence number: 43
# Optimum cluster number: 5
# Summary sentence number: 5
# Document processing time: 00:04
# Total processing time: 01:00:06:17
# ----------------------------------
# Document: 2707
# Document sentence number: 65
# Optimum cluster number: 19
# Summary sentence number: 10
# Document processing time: 00:07
# Total processing time: 01:00:06:24
# ----------------------------------
# Document: 2708
# Document sentence number: 112
# Optimum cluster number: 16
# Summary sentence number: 10
# Document processing time: 00:29
# Total processing time: 01:00:06:54
# ----------------------------------
# Document: 2709
# Document sentence number: 75
# Optimum cluster number: 20
# Summary sentence number: 10
# Document processing time: 00:09
# Total processing time: 01:00:07:04
# ----------------------------------
# Document: 2710
# Document sentence number: 115
# Optimum cluster number: 17
# Summary sentence number: 10
# Document processing time: 00:33
# Total processing time: 01:00:07:37
# ----------------------------------
# Document: 2711
# Document sentence number: 113
# Optimum cluster number: 22
# Summary sentence number: 10
# Document processing time: 00:29
# Total processing time: 01:00:08:06
# ----------------------------------
# Document: 2712
# Document sentence number: 253
# Optimum cluster number: 41
# Summary sentence number: 10
# Document processing time: 01:41
# Total processing time: 01:00:09:48
# ----------------------------------
# Document: 2713
# Document sentence number: 127
# Optimum cluster number: 22
# Summary sentence number: 10
# Document processing time: 00:35
# Total processing time: 01:00:10:24
# ----------------------------------
# Document: 2714
# Document sentence number: 104
# Optimum cluster number: 23
# Summary sentence number: 10
# Document processing time: 00:29
# Total processing time: 01:00:10:53
# ----------------------------------
# Document: 2715
# Document sentence number: 24
# Optimum cluster number: 5
# Summary sentence number: 5
# Document processing time: 00:03
# Total processing time: 01:00:10:57
# ----------------------------------
# Document: 2716
# Document sentence number: 80
# Optimum cluster number: 13
# Summary sentence number: 10
# Document processing time: 00:12
# Total processing time: 01:00:11:09
# ----------------------------------
# Document: 2717
# Document sentence number: 191
# Optimum cluster number: 14
# Summary sentence number: 10
# Document processing time: 01:01
# Total processing time: 01:00:12:11
# ----------------------------------
# Document: 2718
# Document sentence number: 137
# Optimum cluster number: 10
# Summary sentence number: 10
# Document processing time: 00:38
# Total processing time: 01:00:12:49
# ----------------------------------
# Document: 2719
# Document sentence number: 40
# Optimum cluster number: 4
# Summary sentence number: 4
# Document processing time: 00:07
# Total processing time: 01:00:12:57
# ----------------------------------
# Document: 2720
# Document sentence number: 104
# Optimum cluster number: 9
# Summary sentence number: 9
# Document processing time: 00:25
# Total processing time: 01:00:13:23
# ----------------------------------
# Document: 2721
# Document sentence number: 156
# Optimum cluster number: 28
# Summary sentence number: 10
# Document processing time: 00:46
# Total processing time: 01:00:14:09
# ----------------------------------
# Document: 2722
# Document sentence number: 94
# Optimum cluster number: 11
# Summary sentence number: 10
# Document processing time: 00:22
# Total processing time: 01:00:14:31
# ----------------------------------
# Document: 2723
# Document sentence number: 72
# Optimum cluster number: 6
# Summary sentence number: 6
# Document processing time: 00:08
# Total processing time: 01:00:14:40
# ----------------------------------
# Document: 2724
# Document sentence number: 48
# Optimum cluster number: 13
# Summary sentence number: 10
# Document processing time: 00:05
# Total processing time: 01:00:14:46
# ----------------------------------
# Document: 2725
# Document sentence number: 35
# Optimum cluster number: 8
# Summary sentence number: 8
# Document processing time: 00:04
# Total processing time: 01:00:14:50
# ----------------------------------
# Document: 2726
# Document sentence number: 30
# Optimum cluster number: 6
# Summary sentence number: 6
# Document processing time: 00:03
# Total processing time: 01:00:14:53
# ----------------------------------
# Document: 2727
# Document sentence number: 86
# Optimum cluster number: 25
# Summary sentence number: 10
# Document processing time: 00:19
# Total processing time: 01:00:15:13
# ----------------------------------
# Document: 2728
# Document sentence number: 123
# Optimum cluster number: 19
# Summary sentence number: 10
# Document processing time: 00:34
# Total processing time: 01:00:15:48
# ----------------------------------
# Document: 2729
# Document sentence number: 298
# Optimum cluster number: 19
# Summary sentence number: 10
# Document processing time: 01:59
# Total processing time: 01:00:17:48
# ----------------------------------
# Document: 2730
# Document sentence number: 66
# Optimum cluster number: 15
# Summary sentence number: 10
# Document processing time: 00:07
# Total processing time: 01:00:17:55
# ----------------------------------
# Document: 2731
# Document sentence number: 60
# Optimum cluster number: 17
# Summary sentence number: 10
# Document processing time: 00:06
# Total processing time: 01:00:18:02
# ----------------------------------
# Document: 2732
# Document sentence number: 101
# Optimum cluster number: 12
# Summary sentence number: 10
# Document processing time: 00:24
# Total processing time: 01:00:18:27
# ----------------------------------
# Document: 2733
# Document sentence number: 49
# Optimum cluster number: 11
# Summary sentence number: 10
# Document processing time: 00:05
# Total processing time: 01:00:18:33
# ----------------------------------
# Document: 2734
# Document sentence number: 132
# Optimum cluster number: 22
# Summary sentence number: 10
# Document processing time: 00:38
# Total processing time: 01:00:19:11
# ----------------------------------
# Document: 2735
# Document sentence number: 200
# Optimum cluster number: 15
# Summary sentence number: 10
# Document processing time: 01:06
# Total processing time: 01:00:20:18
# ----------------------------------
# Document: 2736
# Document sentence number: 124
# Optimum cluster number: 14
# Summary sentence number: 10
# Document processing time: 00:34
# Total processing time: 01:00:20:53
# ----------------------------------
# Document: 2737
# Document sentence number: 106
# Optimum cluster number: 20
# Summary sentence number: 10
# Document processing time: 00:27
# Total processing time: 01:00:21:20
# ----------------------------------
# Document: 2738
# Document sentence number: 367
# Optimum cluster number: 19
# ######### Error with PageRank
# Summary sentence number: 10
# Document processing time: 02:57
# Total processing time: 01:00:24:17
# ----------------------------------
# Document: 2739
# Document sentence number: 7
# Corpus is less than 9 sentence, summarization didn't apply sentence number: 7
# Document processing time: 00:00
# Total processing time: 01:00:24:17
# ----------------------------------
# Document: 2740
# Document sentence number: 99
# Optimum cluster number: 17
# Summary sentence number: 10
# Document processing time: 00:24
# Total processing time: 01:00:24:42
# ----------------------------------
# Document: 2741
# Document sentence number: 182
# Optimum cluster number: 28
# Summary sentence number: 10
# Document processing time: 00:58
# Total processing time: 01:00:25:40
# ----------------------------------
# Document: 2742
# Document sentence number: 32
# Optimum cluster number: 9
# Summary sentence number: 9
# Document processing time: 00:03
# Total processing time: 01:00:25:44
# ----------------------------------
# Document: 2743
# Document sentence number: 188
# Optimum cluster number: 13
# Summary sentence number: 10
# Document processing time: 01:00
# Total processing time: 01:00:26:45
# ----------------------------------
# Document: 2744
# Document sentence number: 114
# Optimum cluster number: 9
# Summary sentence number: 9
# Document processing time: 00:31
# Total processing time: 01:00:27:16
# ----------------------------------
# Document: 2745
# Document sentence number: 83
# Optimum cluster number: 8
# Summary sentence number: 8
# Document processing time: 00:14
# Total processing time: 01:00:27:30
# ----------------------------------
# Document: 2746
# Document sentence number: 111
# Optimum cluster number: 16
# Summary sentence number: 10
# Document processing time: 00:29
# Total processing time: 01:00:28:00
# ----------------------------------
# Document: 2747
# Document sentence number: 143
# Optimum cluster number: 22
# Summary sentence number: 10
# Document processing time: 00:40
# Total processing time: 01:00:28:40
# ----------------------------------
# Document: 2748
# Document sentence number: 56
# Optimum cluster number: 17
# Summary sentence number: 10
# Document processing time: 00:06
# Total processing time: 01:00:28:46
# ----------------------------------
# Document: 2749
# Document sentence number: 292
# Optimum cluster number: 19
# Summary sentence number: 10
# Document processing time: 01:58
# Total processing time: 01:00:30:44
# ----------------------------------
# Document: 2750
# Document sentence number: 68
# Optimum cluster number: 19
# Summary sentence number: 10
# Document processing time: 00:07
# Total processing time: 01:00:30:52
# ----------------------------------
# Document: 2751
# Document sentence number: 64
# Optimum cluster number: 5
# Summary sentence number: 5
# Document processing time: 00:07
# Total processing time: 01:00:31:00
# ----------------------------------
# Document: 2752
# Document sentence number: 71
# Optimum cluster number: 14
# Summary sentence number: 10
# Document processing time: 00:08
# Total processing time: 01:00:31:08
# ----------------------------------
# Document: 2753
# Document sentence number: 77
# Optimum cluster number: 14
# Summary sentence number: 10
# Document processing time: 00:09
# Total processing time: 01:00:31:18
# ----------------------------------
# Document: 2754
# Document sentence number: 71
# Optimum cluster number: 8
# Summary sentence number: 8
# Document processing time: 00:08
# Total processing time: 01:00:31:27
# ----------------------------------
# Document: 2755
# Document sentence number: 189
# Optimum cluster number: 14
# Summary sentence number: 10
# Document processing time: 01:02
# Total processing time: 01:00:32:30
# ----------------------------------
# Document: 2756
# Document sentence number: 88
# Optimum cluster number: 11
# Summary sentence number: 10
# Document processing time: 00:20
# Total processing time: 01:00:32:50
# ----------------------------------
# Document: 2757
# Document sentence number: 98
# Optimum cluster number: 21
# Summary sentence number: 10
# Document processing time: 00:23
# Total processing time: 01:00:33:14
# ----------------------------------
# Document: 2758
# Document sentence number: 38
# Optimum cluster number: 6
# Summary sentence number: 6
# Document processing time: 00:04
# Total processing time: 01:00:33:18
# ----------------------------------
# Document: 2759
# Document sentence number: 152
# Optimum cluster number: 36
# Summary sentence number: 10
# Document processing time: 00:44
# Total processing time: 01:00:34:02
# ----------------------------------
# Document: 2760
# Document sentence number: 127
# Optimum cluster number: 14
# Summary sentence number: 10
# Document processing time: 00:35
# Total processing time: 01:00:34:38
# ----------------------------------
# Document: 2761
# Document sentence number: 68
# Optimum cluster number: 17
# Summary sentence number: 10
# Document processing time: 00:07
# Total processing time: 01:00:34:46
# ----------------------------------
# Document: 2762
# Document sentence number: 181
# Optimum cluster number: 19
# Summary sentence number: 10
# Document processing time: 00:57
# Total processing time: 01:00:35:44
# ----------------------------------
# Document: 2763
# Document sentence number: 65
# Optimum cluster number: 15
# Summary sentence number: 10
# Document processing time: 00:07
# Total processing time: 01:00:35:51
# ----------------------------------
# Document: 2764
# Document sentence number: 78
# Optimum cluster number: 8
# Summary sentence number: 8
# Document processing time: 00:10
# Total processing time: 01:00:36:01
# ----------------------------------
# Document: 2765
# Document sentence number: 144
# Optimum cluster number: 35
# Summary sentence number: 10
# Document processing time: 00:46
# Total processing time: 01:00:36:47
# ----------------------------------
# Document: 2766
# Document sentence number: 29
# Optimum cluster number: 7
# Summary sentence number: 7
# Document processing time: 00:03
# Total processing time: 01:00:36:51
# ----------------------------------
# Document: 2767
# Document sentence number: 72
# Optimum cluster number: 9
# Summary sentence number: 9
# Document processing time: 00:08
# Total processing time: 01:00:37:00
# ----------------------------------
# Document: 2768
# Document sentence number: 60
# Optimum cluster number: 18
# Summary sentence number: 10
# Document processing time: 00:06
# Total processing time: 01:00:37:07
# ----------------------------------
# Document: 2769
# Document sentence number: 50
# Optimum cluster number: 4
# Summary sentence number: 4
# Document processing time: 00:05
# Total processing time: 01:00:37:12
# ----------------------------------
# Document: 2770
# Document sentence number: 55
# Optimum cluster number: 14
# Summary sentence number: 10
# Document processing time: 00:06
# Total processing time: 01:00:37:19
# ----------------------------------
# Document: 2771
# Document sentence number: 59
# Optimum cluster number: 10
# Summary sentence number: 10
# Document processing time: 00:06
# Total processing time: 01:00:37:25
# ----------------------------------
# Document: 2772
# Document sentence number: 70
# Optimum cluster number: 14
# Summary sentence number: 10
# Document processing time: 00:08
# Total processing time: 01:00:37:34
# ----------------------------------
# Document: 2773
# Document sentence number: 123
# Optimum cluster number: 23
# Summary sentence number: 10
# Document processing time: 00:35
# Total processing time: 01:00:38:09
# ----------------------------------
# Document: 2774
# Document sentence number: 133
# Optimum cluster number: 10
# Summary sentence number: 10
# Document processing time: 00:37
# Total processing time: 01:00:38:47
# ----------------------------------
# Document: 2775
# Document sentence number: 28
# Optimum cluster number: 6
# Summary sentence number: 6
# Document processing time: 00:03
# Total processing time: 01:00:38:51
# ----------------------------------
# Document: 2776
# Document sentence number: 73
# Optimum cluster number: 18
# Summary sentence number: 10
# Document processing time: 00:09
# Total processing time: 01:00:39:00
# ----------------------------------
# Document: 2777
# Document sentence number: 67
# Optimum cluster number: 11
# Summary sentence number: 10
# Document processing time: 00:08
# Total processing time: 01:00:39:09
# ----------------------------------
# Document: 2778
# Document sentence number: 21
# Optimum cluster number: 5
# Summary sentence number: 5
# Document processing time: 00:03
# Total processing time: 01:00:39:12
# ----------------------------------
# Document: 2779
# Document sentence number: 74
# Optimum cluster number: 16
# Summary sentence number: 10
# Document processing time: 00:11
# Total processing time: 01:00:39:23
# ----------------------------------
# Document: 2780
# Document sentence number: 90
# Optimum cluster number: 12
# Summary sentence number: 10
# Document processing time: 00:22
# Total processing time: 01:00:39:45
# ----------------------------------
# Document: 2781
# Document sentence number: 330
# Optimum cluster number: 19
# Summary sentence number: 10
# Document processing time: 02:34
# Total processing time: 01:00:42:20
# ----------------------------------
# Document: 2782
# Document sentence number: 28
# Optimum cluster number: 4
# Summary sentence number: 4
# Document processing time: 00:03
# Total processing time: 01:00:42:23
# ----------------------------------
# Document: 2783
# Document sentence number: 102
# Optimum cluster number: 10
# Summary sentence number: 10
# Document processing time: 00:27
# Total processing time: 01:00:42:50
# ----------------------------------
# Document: 2784
# Document sentence number: 65
# Optimum cluster number: 7
# Summary sentence number: 7
# Document processing time: 00:07
# Total processing time: 01:00:42:58
# ----------------------------------
# Document: 2785
# Document sentence number: 89
# Optimum cluster number: 28
# Summary sentence number: 10
# Document processing time: 00:21
# Total processing time: 01:00:43:20
# ----------------------------------
# Document: 2786
# Document sentence number: 196
# Optimum cluster number: 24
# Summary sentence number: 10
# Document processing time: 01:11
# Total processing time: 01:00:44:31
# ----------------------------------
# Document: 2787
# Document sentence number: 45
# Optimum cluster number: 6
# Summary sentence number: 6
# Document processing time: 00:05
# Total processing time: 01:00:44:37
# ----------------------------------
# Document: 2788
# Document sentence number: 56
# Optimum cluster number: 8
# Summary sentence number: 8
# Document processing time: 00:06
# Total processing time: 01:00:44:43
# ----------------------------------
# Document: 2789
# Document sentence number: 28
# Optimum cluster number: 5
# Summary sentence number: 5
# Document processing time: 00:03
# Total processing time: 01:00:44:47
# ----------------------------------
# Document: 2790
# Document sentence number: 105
# Optimum cluster number: 23
# Summary sentence number: 10
# Document processing time: 00:28
# Total processing time: 01:00:45:15
# ----------------------------------
# Document: 2791
# Document sentence number: 94
# Optimum cluster number: 26
# Summary sentence number: 10
# Document processing time: 00:22
# Total processing time: 01:00:45:38
# ----------------------------------
# Document: 2792
# Document sentence number: 50
# Optimum cluster number: 5
# Summary sentence number: 5
# Document processing time: 00:07
# Total processing time: 01:00:45:46
# ----------------------------------
# Document: 2793
# Document sentence number: 67
# Optimum cluster number: 11
# Summary sentence number: 10
# Document processing time: 00:07
# Total processing time: 01:00:45:54
# ----------------------------------
# Document: 2794
# Document sentence number: 81
# Optimum cluster number: 15
# Summary sentence number: 10
# Document processing time: 00:14
# Total processing time: 01:00:46:08
# ----------------------------------
# Document: 2795
# Document sentence number: 194
# Optimum cluster number: 22
# Summary sentence number: 10
# Document processing time: 01:06
# Total processing time: 01:00:47:14
# ----------------------------------
# Document: 2796
# Document sentence number: 35
# Optimum cluster number: 5
# Summary sentence number: 5
# Document processing time: 00:04
# Total processing time: 01:00:47:18
# ----------------------------------
# Document: 2797
# Document sentence number: 53
# Optimum cluster number: 8
# Summary sentence number: 8
# Document processing time: 00:05
# Total processing time: 01:00:47:24
# ----------------------------------
# Document: 2798
# Document sentence number: 53
# Optimum cluster number: 5
# Summary sentence number: 5
# Document processing time: 00:05
# Total processing time: 01:00:47:30
# ----------------------------------
# Document: 2799
# Document sentence number: 63
# Optimum cluster number: 9
# Summary sentence number: 9
# Document processing time: 00:07
# Total processing time: 01:00:47:38
# ----------------------------------
# Document: 2800
# Document sentence number: 33
# Optimum cluster number: 8
# Summary sentence number: 8
# Document processing time: 00:04
# Total processing time: 01:00:47:42
# ----------------------------------
# Document: 2801
# Document sentence number: 87
# Optimum cluster number: 24
# Summary sentence number: 10
# Document processing time: 00:21
# Total processing time: 01:00:48:03
# ----------------------------------
# Document: 2802
# Document sentence number: 48
# Optimum cluster number: 13
# Summary sentence number: 10
# Document processing time: 00:05
# Total processing time: 01:00:48:08
# ----------------------------------
# Document: 2803
# Document sentence number: 202
# Optimum cluster number: 35
# Summary sentence number: 10
# Document processing time: 01:10
# Total processing time: 01:00:49:18
# ----------------------------------
# Document: 2804
# Document sentence number: 153
# Optimum cluster number: 33
# Summary sentence number: 10
# Document processing time: 00:47
# Total processing time: 01:00:50:06
# ----------------------------------
# Document: 2805
# Document sentence number: 45
# Optimum cluster number: 12
# Summary sentence number: 10
# Document processing time: 00:05
# Total processing time: 01:00:50:11
# ----------------------------------
# Document: 2806
# Document sentence number: 45
# Optimum cluster number: 8
# Summary sentence number: 8
# Document processing time: 00:05
# Total processing time: 01:00:50:16
# ----------------------------------
# Document: 2807
# Document sentence number: 44
# Optimum cluster number: 12
# Summary sentence number: 10
# Document processing time: 00:05
# Total processing time: 01:00:50:22
# ----------------------------------
# Document: 2808
# Document sentence number: 180
# Optimum cluster number: 17
# Summary sentence number: 10
# Document processing time: 00:58
# Total processing time: 01:00:51:20
# ----------------------------------
# Document: 2809
# Document sentence number: 171
# Optimum cluster number: 19
# Summary sentence number: 10
# Document processing time: 00:58
# Total processing time: 01:00:52:18
# ----------------------------------
# Document: 2810
# Document sentence number: 149
# Optimum cluster number: 10
# Summary sentence number: 10
# Document processing time: 00:44
# Total processing time: 01:00:53:02
# ----------------------------------
# Document: 2811
# Document sentence number: 1302
# Optimum cluster number: 205
# Summary sentence number: 10
# Document processing time: 03:54
# Total processing time: 01:01:56:57
# ----------------------------------
# Document: 2812
# Document sentence number: 42
# Optimum cluster number: 9
# Summary sentence number: 9
# Document processing time: 00:05
# Total processing time: 01:01:57:02
# ----------------------------------
# Document: 2813
# Document sentence number: 51
# Optimum cluster number: 9
# Summary sentence number: 9
# Document processing time: 00:05
# Total processing time: 01:01:57:08
# ----------------------------------
# Document: 2814
# Document sentence number: 138
# Optimum cluster number: 18
# Summary sentence number: 10
# Document processing time: 00:42
# Total processing time: 01:01:57:50
# ----------------------------------
# Document: 2815
# Document sentence number: 204
# Optimum cluster number: 37
# Summary sentence number: 10
# Document processing time: 01:14
# Total processing time: 01:01:59:04
# ----------------------------------
# Document: 2816
# Document sentence number: 27
# Optimum cluster number: 7
# Summary sentence number: 7
# Document processing time: 00:03
# Total processing time: 01:01:59:08
# ----------------------------------
# Document: 2817
# Document sentence number: 59
# Optimum cluster number: 7
# Summary sentence number: 7
# Document processing time: 00:07
# Total processing time: 01:01:59:15
# ----------------------------------
# Document: 2818
# Document sentence number: 93
# Optimum cluster number: 7
# Summary sentence number: 7
# Document processing time: 00:22
# Total processing time: 01:01:59:38
# ----------------------------------
# Document: 2819
# Document sentence number: 81
# Optimum cluster number: 19
# Summary sentence number: 10
# Document processing time: 00:13
# Total processing time: 01:01:59:52
# ----------------------------------
# Document: 2820
# Document sentence number: 309
# Optimum cluster number: 70
# Summary sentence number: 10
# Document processing time: 02:24
# Total processing time: 01:02:02:16
# ----------------------------------
# Document: 2821
# Document sentence number: 41
# Optimum cluster number: 12
# Summary sentence number: 10
# Document processing time: 00:04
# Total processing time: 01:02:02:21
# ----------------------------------
# Document: 2822
# Document sentence number: 7
# Corpus is less than 9 sentence, summarization didn't apply sentence number: 7
# Document processing time: 00:00
# Total processing time: 01:02:02:21
# ----------------------------------
# Document: 2823
# Document sentence number: 166
# Optimum cluster number: 6
# Summary sentence number: 6
# Document processing time: 00:52
# Total processing time: 01:02:03:14
# ----------------------------------
# Document: 2824
# Document sentence number: 145
# Optimum cluster number: 20
# Summary sentence number: 10
# Document processing time: 00:45
# Total processing time: 01:02:03:59
# ----------------------------------
# Document: 2825
# Document sentence number: 151
# Optimum cluster number: 6
# Summary sentence number: 6
# Document processing time: 00:46
# Total processing time: 01:02:04:45
# ----------------------------------
# Document: 2826
# Document sentence number: 27
# Optimum cluster number: 7
# Summary sentence number: 7
# Document processing time: 00:03
# Total processing time: 01:02:04:49
# ----------------------------------
# Document: 2827
# Document sentence number: 36
# Optimum cluster number: 5
# Summary sentence number: 5
# Document processing time: 00:04
# Total processing time: 01:02:04:54
# ----------------------------------
# Document: 2828
# Document sentence number: 26
# Optimum cluster number: 6
# Summary sentence number: 6
# Document processing time: 00:03
# Total processing time: 01:02:04:57
# ----------------------------------
# Document: 2829
# Document sentence number: 47
# Optimum cluster number: 10
# Summary sentence number: 10
# Document processing time: 00:05
# Total processing time: 01:02:05:02
# ----------------------------------
# Document: 2830
# Document sentence number: 42
# Optimum cluster number: 6
# Summary sentence number: 6
# Document processing time: 00:05
# Total processing time: 01:02:05:07
# ----------------------------------
# Document: 2831
# Document sentence number: 49
# Optimum cluster number: 7
# Summary sentence number: 7
# Document processing time: 00:05
# Total processing time: 01:02:05:13
# ----------------------------------
# Document: 2832
# Document sentence number: 66
# Optimum cluster number: 5
# Summary sentence number: 5
# Document processing time: 00:10
# Total processing time: 01:02:05:24
# ----------------------------------
# Document: 2833
# Document sentence number: 74
# Optimum cluster number: 19
# Summary sentence number: 10
# Document processing time: 00:09
# Total processing time: 01:02:05:33
# ----------------------------------
# Document: 2834
# Document sentence number: 84
# Optimum cluster number: 15
# Summary sentence number: 10
# Document processing time: 00:14
# Total processing time: 01:02:05:48
# ----------------------------------
# Document: 2835
# Document sentence number: 36
# Optimum cluster number: 7
# Summary sentence number: 7
# Document processing time: 00:04
# Total processing time: 01:02:05:52
# ----------------------------------
# Document: 2836
# Document sentence number: 46
# Optimum cluster number: 4
# Summary sentence number: 4
# Document processing time: 00:05
# Total processing time: 01:02:05:58
# ----------------------------------
# Document: 2837
# Document sentence number: 69
# Optimum cluster number: 8
# Summary sentence number: 8
# Document processing time: 00:08
# Total processing time: 01:02:06:06
# ----------------------------------
# Document: 2838
# Document sentence number: 83
# Optimum cluster number: 8
# Summary sentence number: 8
# Document processing time: 00:17
# Total processing time: 01:02:06:24
# ----------------------------------
# Document: 2839
# Document sentence number: 41
# Optimum cluster number: 7
# Summary sentence number: 7
# Document processing time: 00:05
# Total processing time: 01:02:06:29
# ----------------------------------
# Document: 2840
# Document sentence number: 112
# Optimum cluster number: 11
# Summary sentence number: 10
# Document processing time: 00:29
# Total processing time: 01:02:06:59
# ----------------------------------
# Document: 2841
# Document sentence number: 149
# Optimum cluster number: 10
# Summary sentence number: 10
# Document processing time: 00:46
# Total processing time: 01:02:07:46
# ----------------------------------
# Document: 2842
# Document sentence number: 54
# Optimum cluster number: 14
# Summary sentence number: 10
# Document processing time: 00:06
# Total processing time: 01:02:07:52
# ----------------------------------
# Document: 2843
# Document sentence number: 104
# Optimum cluster number: 29
# Summary sentence number: 10
# Document processing time: 00:27
# Total processing time: 01:02:08:20
# ----------------------------------
# Document: 2844
# Document sentence number: 89
# Optimum cluster number: 13
# Summary sentence number: 10
# Document processing time: 00:21
# Total processing time: 01:02:08:42
# ----------------------------------
# Document: 2845
# Document sentence number: 55
# Optimum cluster number: 8
# Summary sentence number: 8
# Document processing time: 00:06
# Total processing time: 01:02:08:48
# ----------------------------------
# Document: 2846
# Document sentence number: 95
# Optimum cluster number: 27
# Summary sentence number: 10
# Document processing time: 00:23
# Total processing time: 01:02:09:12
# ----------------------------------
# Document: 2847
# Document sentence number: 166
# Optimum cluster number: 34
# Summary sentence number: 10
# Document processing time: 00:52
# Total processing time: 01:02:10:04
# ----------------------------------
# Document: 2848
# Document sentence number: 35
# Optimum cluster number: 10
# Summary sentence number: 10
# Document processing time: 00:04
# Total processing time: 01:02:10:09
# ----------------------------------
# Document: 2849
# Document sentence number: 97
# Optimum cluster number: 19
# Summary sentence number: 10
# Document processing time: 00:28
# Total processing time: 01:02:10:37
# ----------------------------------
# Document: 2850
# Document sentence number: 86
# Optimum cluster number: 13
# Summary sentence number: 10
# Document processing time: 00:21
# Total processing time: 01:02:10:58
# ----------------------------------
# Document: 2851
# Document sentence number: 129
# Optimum cluster number: 32
# Summary sentence number: 10
# Document processing time: 00:37
# Total processing time: 01:02:11:36
# ----------------------------------
# Document: 2852
# Document sentence number: 44
# Optimum cluster number: 11
# Summary sentence number: 10
# Document processing time: 00:04
# Total processing time: 01:02:11:41
# ----------------------------------
# Document: 2853
# Document sentence number: 99
# Optimum cluster number: 16
# Summary sentence number: 10
# Document processing time: 00:25
# Total processing time: 01:02:12:06
# ----------------------------------
# Document: 2854
# Document sentence number: 100
# Optimum cluster number: 30
# Summary sentence number: 10
# Document processing time: 00:25
# Total processing time: 01:02:12:31
# ----------------------------------
# Document: 2855
# Document sentence number: 35
# Optimum cluster number: 10
# Summary sentence number: 10
# Document processing time: 00:04
# Total processing time: 01:02:12:35
# ----------------------------------
# Document: 2856
# Document sentence number: 77
# Optimum cluster number: 8
# Summary sentence number: 8
# Document processing time: 00:09
# Total processing time: 01:02:12:45
# ----------------------------------
# Document: 2857
# Document sentence number: 78
# Optimum cluster number: 13
# Summary sentence number: 10
# Document processing time: 00:10
# Total processing time: 01:02:12:55
# ----------------------------------
# Document: 2858
# Document sentence number: 105
# Optimum cluster number: 10
# Summary sentence number: 10
# Document processing time: 00:27
# Total processing time: 01:02:13:22
# ----------------------------------
# Document: 2859
# Document sentence number: 80
# Optimum cluster number: 10
# Summary sentence number: 10
# Document processing time: 00:16
# Total processing time: 01:02:13:38
# ----------------------------------
# Document: 2860
# Document sentence number: 110
# Optimum cluster number: 11
# Summary sentence number: 10
# Document processing time: 00:28
# Total processing time: 01:02:14:07
# ----------------------------------
# Document: 2861
# Document sentence number: 357
# Optimum cluster number: 16
# Summary sentence number: 10
# Document processing time: 03:04
# Total processing time: 01:02:17:12
# ----------------------------------
# Document: 2862
# Document sentence number: 161
# Optimum cluster number: 17
# Summary sentence number: 10
# Document processing time: 00:52
# Total processing time: 01:02:18:04
# ----------------------------------
# Document: 2863
# Document sentence number: 172
# Optimum cluster number: 9
# Summary sentence number: 9
# Document processing time: 00:55
# Total processing time: 01:02:19:00
# ----------------------------------
# Document: 2864
# Document sentence number: 152
# Optimum cluster number: 49
# Summary sentence number: 10
# Document processing time: 00:47
# Total processing time: 01:02:19:47
# ----------------------------------
# Document: 2865
# Document sentence number: 90
# Optimum cluster number: 6
# Summary sentence number: 6
# Document processing time: 00:22
# Total processing time: 01:02:20:10
# ----------------------------------
# Document: 2866
# Document sentence number: 52
# Optimum cluster number: 10
# Summary sentence number: 10
# Document processing time: 00:05
# Total processing time: 01:02:20:16
# ----------------------------------
# Document: 2867
# Document sentence number: 83
# Optimum cluster number: 9
# Summary sentence number: 9
# Document processing time: 00:14
# Total processing time: 01:02:20:31
# ----------------------------------
# Document: 2868
# Document sentence number: 197
# Optimum cluster number: 6
# Summary sentence number: 6
# Document processing time: 01:07
# Total processing time: 01:02:21:38
# ----------------------------------
# Document: 2869
# Document sentence number: 151
# Optimum cluster number: 17
# Summary sentence number: 10
# Document processing time: 00:50
# Total processing time: 01:02:22:28
# ----------------------------------
# Document: 2870
# Document sentence number: 256
# Optimum cluster number: 45
# Summary sentence number: 10
# Document processing time: 01:46
# Total processing time: 01:02:24:15
# ----------------------------------
# Document: 2871
# Document sentence number: 100
# Optimum cluster number: 19
# Summary sentence number: 10
# Document processing time: 00:27
# Total processing time: 01:02:24:42
# ----------------------------------
# Document: 2872
# Document sentence number: 43
# Optimum cluster number: 4
# Summary sentence number: 4
# Document processing time: 00:05
# Total processing time: 01:02:24:48
# ----------------------------------
# Document: 2873
# Document sentence number: 47
# Optimum cluster number: 11
# Summary sentence number: 10
# Document processing time: 00:05
# Total processing time: 01:02:24:53
# ----------------------------------
# Document: 2874
# Document sentence number: 107
# Optimum cluster number: 12
# Summary sentence number: 10
# Document processing time: 00:28
# Total processing time: 01:02:25:22
# ----------------------------------
# Document: 2875
# Document sentence number: 183
# Optimum cluster number: 10
# Summary sentence number: 10
# Document processing time: 01:01
# Total processing time: 01:02:26:23
# ----------------------------------
# Document: 2876
# Document sentence number: 57
# Optimum cluster number: 6
# Summary sentence number: 6
# Document processing time: 00:07
# Total processing time: 01:02:26:31
# ----------------------------------
# Document: 2877
# Document sentence number: 71
# Optimum cluster number: 4
# Summary sentence number: 4
# Document processing time: 00:08
# Total processing time: 01:02:26:39
# ----------------------------------
# Document: 2878
# Document sentence number: 118
# Optimum cluster number: 15
# Summary sentence number: 10
# Document processing time: 00:33
# Total processing time: 01:02:27:13
# ----------------------------------
# Document: 2879
# Document sentence number: 24
# Optimum cluster number: 7
# Summary sentence number: 7
# Document processing time: 00:03
# Total processing time: 01:02:27:17
# ----------------------------------
# Document: 2880
# Document sentence number: 57
# Optimum cluster number: 14
# Summary sentence number: 10
# Document processing time: 00:06
# Total processing time: 01:02:27:24
# ----------------------------------
# Document: 2881
# Document sentence number: 34
# Optimum cluster number: 6
# Summary sentence number: 6
# Document processing time: 00:04
# Total processing time: 01:02:27:29
# ----------------------------------
# Document: 2882
# Document sentence number: 7
# Corpus is less than 9 sentence, summarization didn't apply sentence number: 7
# Document processing time: 00:00
# Total processing time: 01:02:27:29
# ----------------------------------
# Document: 2883
# Document sentence number: 151
# Optimum cluster number: 13
# Summary sentence number: 10
# Document processing time: 00:46
# Total processing time: 01:02:28:15
# ----------------------------------
# Document: 2884
# Document sentence number: 69
# Optimum cluster number: 8
# Summary sentence number: 8
# Document processing time: 00:08
# Total processing time: 01:02:28:24
# ----------------------------------
# Document: 2885
# Document sentence number: 115
# Optimum cluster number: 8
# Summary sentence number: 8
# Document processing time: 00:33
# Total processing time: 01:02:28:57
# ----------------------------------
# Document: 2886
# Document sentence number: 72
# Optimum cluster number: 17
# Summary sentence number: 10
# Document processing time: 00:09
# Total processing time: 01:02:29:06
# ----------------------------------
# Document: 2887
# Document sentence number: 54
# Optimum cluster number: 10
# Summary sentence number: 10
# Document processing time: 00:06
# Total processing time: 01:02:29:13
# ----------------------------------
# Document: 2888
# Document sentence number: 49
# Optimum cluster number: 9
# Summary sentence number: 9
# Document processing time: 00:06
# Total processing time: 01:02:29:19
# ----------------------------------
# Document: 2889
# Document sentence number: 123
# Optimum cluster number: 9
# Summary sentence number: 9
# Document processing time: 00:34
# Total processing time: 01:02:29:54
# ----------------------------------
# Document: 2890
# Document sentence number: 53
# Optimum cluster number: 7
# Summary sentence number: 7
# Document processing time: 00:06
# Total processing time: 01:02:30:01
# ----------------------------------
# Document: 2891
# Document sentence number: 90
# Optimum cluster number: 24
# Summary sentence number: 10
# Document processing time: 00:23
# Total processing time: 01:02:30:24
# ----------------------------------
# Document: 2892
# Document sentence number: 189
# Optimum cluster number: 12
# Summary sentence number: 10
# Document processing time: 01:04
# Total processing time: 01:02:31:28
# ----------------------------------
# Document: 2893
# Document sentence number: 77
# Optimum cluster number: 21
# Summary sentence number: 10
# Document processing time: 00:09
# Total processing time: 01:02:31:38
# ----------------------------------
# Document: 2894
# Document sentence number: 278
# Optimum cluster number: 11
# Summary sentence number: 10
# Document processing time: 01:58
# Total processing time: 01:02:33:36
# ----------------------------------
# Document: 2895
# Document sentence number: 56
# Optimum cluster number: 11
# Summary sentence number: 10
# Document processing time: 00:06
# Total processing time: 01:02:33:43
# ----------------------------------
# Document: 2896
# Document sentence number: 32
# Optimum cluster number: 8
# Summary sentence number: 8
# Document processing time: 00:04
# Total processing time: 01:02:33:47
# ----------------------------------
# Document: 2897
# Document sentence number: 93
# Optimum cluster number: 10
# Summary sentence number: 10
# Document processing time: 00:23
# Total processing time: 01:02:34:10
# ----------------------------------
# Document: 2898
# Document sentence number: 71
# Optimum cluster number: 8
# Summary sentence number: 8
# Document processing time: 00:08
# Total processing time: 01:02:34:19
# ----------------------------------
# Document: 2899
# Document sentence number: 43
# Optimum cluster number: 13
# Summary sentence number: 10
# Document processing time: 00:05
# Total processing time: 01:02:34:24
# ----------------------------------
# Document: 2900
# Document sentence number: 65
# Optimum cluster number: 15
# Summary sentence number: 10
# Document processing time: 00:07
# Total processing time: 01:02:34:31
# ----------------------------------
# Document: 2901
# Document sentence number: 106
# Optimum cluster number: 32
# Summary sentence number: 10
# Document processing time: 00:28
# Total processing time: 01:02:35:00
# ----------------------------------
# Document: 2902
# Document sentence number: 198
# Optimum cluster number: 54
# Summary sentence number: 10
# Document processing time: 01:11
# Total processing time: 01:02:36:12
# ----------------------------------
# Document: 2903
# Document sentence number: 71
# Optimum cluster number: 6
# Summary sentence number: 6
# Document processing time: 00:11
# Total processing time: 01:02:36:23
# ----------------------------------
# Document: 2904
# Document sentence number: 40
# Optimum cluster number: 6
# Summary sentence number: 6
# Document processing time: 00:04
# Total processing time: 01:02:36:28
# ----------------------------------
# Document: 2905
# Document sentence number: 89
# Optimum cluster number: 26
# Summary sentence number: 10
# Document processing time: 00:21
# Total processing time: 01:02:36:50
# ----------------------------------
# Document: 2906
# Document sentence number: 62
# Optimum cluster number: 10
# Summary sentence number: 10
# Document processing time: 00:07
# Total processing time: 01:02:36:57
# ----------------------------------
# Document: 2907
# Document sentence number: 167
# Optimum cluster number: 17
# Summary sentence number: 10
# Document processing time: 00:51
# Total processing time: 01:02:37:49
# ----------------------------------
# Document: 2908
# Document sentence number: 255
# Optimum cluster number: 11
# Summary sentence number: 10
# Document processing time: 01:46
# Total processing time: 01:02:39:35
# ----------------------------------
# Document: 2909
# Document sentence number: 59
# Optimum cluster number: 14
# Summary sentence number: 10
# Document processing time: 00:07
# Total processing time: 01:02:39:43
# ----------------------------------
# Document: 2910
# Document sentence number: 23
# Optimum cluster number: 5
# Summary sentence number: 5
# Document processing time: 00:03
# Total processing time: 01:02:39:46
# ----------------------------------
# Document: 2911
# Document sentence number: 54
# Optimum cluster number: 8
# Summary sentence number: 8
# Document processing time: 00:06
# Total processing time: 01:02:39:53
# ----------------------------------
# Document: 2912
# Document sentence number: 39
# Optimum cluster number: 9
# Summary sentence number: 9
# Document processing time: 00:05
# Total processing time: 01:02:39:58
# ----------------------------------
# Document: 2913
# Document sentence number: 76
# Optimum cluster number: 9
# Summary sentence number: 9
# Document processing time: 00:09
# Total processing time: 01:02:40:08
# ----------------------------------
# Document: 2914
# Document sentence number: 66
# Optimum cluster number: 6
# Summary sentence number: 6
# Document processing time: 00:08
# Total processing time: 01:02:40:16
# ----------------------------------
# Document: 2915
# Document sentence number: 187
# Optimum cluster number: 12
# Summary sentence number: 10
# Document processing time: 01:06
# Total processing time: 01:02:41:22
# ----------------------------------
# Document: 2916
# Document sentence number: 138
# Optimum cluster number: 25
# Summary sentence number: 10
# Document processing time: 00:42
# Total processing time: 01:02:42:04
# ----------------------------------
# Document: 2917
# Document sentence number: 166
# Optimum cluster number: 20
# Summary sentence number: 10
# Document processing time: 00:54
# Total processing time: 01:02:42:59
# ----------------------------------
# Document: 2918
# Document sentence number: 37
# Optimum cluster number: 6
# Summary sentence number: 6
# Document processing time: 00:04
# Total processing time: 01:02:43:04
# ----------------------------------
# Document: 2919
# Document sentence number: 55
# Optimum cluster number: 14
# Summary sentence number: 10
# Document processing time: 00:06
# Total processing time: 01:02:43:10
# ----------------------------------
# Document: 2920
# Document sentence number: 69
# Optimum cluster number: 7
# Summary sentence number: 7
# Document processing time: 00:08
# Total processing time: 01:02:43:19
# ----------------------------------
# Document: 2921
# Document sentence number: 33
# Optimum cluster number: 9
# Summary sentence number: 9
# Document processing time: 00:04
# Total processing time: 01:02:43:23
# ----------------------------------
# Document: 2922
# Document sentence number: 57
# Optimum cluster number: 14
# Summary sentence number: 10
# Document processing time: 00:06
# Total processing time: 01:02:43:30
# ----------------------------------
# Document: 2923
# Document sentence number: 63
# Optimum cluster number: 13
# Summary sentence number: 10
# Document processing time: 00:07
# Total processing time: 01:02:43:38
# ----------------------------------
# Document: 2924
# Document sentence number: 110
# Optimum cluster number: 10
# Summary sentence number: 10
# Document processing time: 00:29
# Total processing time: 01:02:44:07
# ----------------------------------
# Document: 2925
# Document sentence number: 87
# Optimum cluster number: 15
# Summary sentence number: 10
# Document processing time: 00:21
# Total processing time: 01:02:44:29
# ----------------------------------
# Document: 2926
# Document sentence number: 72
# Optimum cluster number: 20
# Summary sentence number: 10
# Document processing time: 00:11
# Total processing time: 01:02:44:40
# ----------------------------------
# Document: 2927
# Document sentence number: 122
# Optimum cluster number: 13
# Summary sentence number: 10
# Document processing time: 00:35
# Total processing time: 01:02:45:15
# ----------------------------------
# Document: 2928
# Document sentence number: 250
# Optimum cluster number: 16
# Summary sentence number: 10
# Document processing time: 01:42
# Total processing time: 01:02:46:57
# ----------------------------------
# Document: 2929
# Document sentence number: 94
# Optimum cluster number: 13
# Summary sentence number: 10
# Document processing time: 00:23
# Total processing time: 01:02:47:20
# ----------------------------------
# Document: 2930
# Document sentence number: 307
# Optimum cluster number: 20
# Summary sentence number: 10
# Document processing time: 02:23
# Total processing time: 01:02:49:44
# ----------------------------------
# Document: 2931
# Document sentence number: 32
# Optimum cluster number: 4
# Summary sentence number: 4
# Document processing time: 00:03
# Total processing time: 01:02:49:48
# ----------------------------------
# Document: 2932
# Document sentence number: 44
# Optimum cluster number: 8
# Summary sentence number: 8
# Document processing time: 00:05
# Total processing time: 01:02:49:53
# ----------------------------------
# Document: 2933
# Document sentence number: 68
# Optimum cluster number: 15
# Summary sentence number: 10
# Document processing time: 00:08
# Total processing time: 01:02:50:01
# ----------------------------------
# Document: 2934
# Document sentence number: 100
# Optimum cluster number: 11
# Summary sentence number: 10
# Document processing time: 00:25
# Total processing time: 01:02:50:27
# ----------------------------------
# Document: 2935
# Document sentence number: 86
# Optimum cluster number: 21
# Summary sentence number: 10
# Document processing time: 00:21
# Total processing time: 01:02:50:48
# ----------------------------------
# Document: 2936
# Document sentence number: 96
# Optimum cluster number: 24
# Summary sentence number: 10
# Document processing time: 00:24
# Total processing time: 01:02:51:13
# ----------------------------------
# Document: 2937
# Document sentence number: 55
# Optimum cluster number: 17
# Summary sentence number: 10
# Document processing time: 00:06
# Total processing time: 01:02:51:19
# ----------------------------------
# Document: 2938
# Document sentence number: 68
# Optimum cluster number: 13
# Summary sentence number: 10
# Document processing time: 00:08
# Total processing time: 01:02:51:27
# ----------------------------------
# Document: 2939
# Document sentence number: 90
# Optimum cluster number: 15
# Summary sentence number: 10
# Document processing time: 00:22
# Total processing time: 01:02:51:50
# ----------------------------------
# Document: 2940
# Document sentence number: 78
# Optimum cluster number: 21
# Summary sentence number: 10
# Document processing time: 00:10
# Total processing time: 01:02:52:00
# ----------------------------------
# Document: 2941
# Document sentence number: 176
# Optimum cluster number: 10
# Summary sentence number: 10
# Document processing time: 00:57
# Total processing time: 01:02:52:58
# ----------------------------------
# Document: 2942
# Document sentence number: 63
# Optimum cluster number: 16
# Summary sentence number: 10
# Document processing time: 00:07
# Total processing time: 01:02:53:06
# ----------------------------------
# Document: 2943
# Document sentence number: 60
# Optimum cluster number: 8
# Summary sentence number: 8
# Document processing time: 00:07
# Total processing time: 01:02:53:13
# ----------------------------------
# Document: 2944
# Document sentence number: 38
# Optimum cluster number: 8
# Summary sentence number: 8
# Document processing time: 00:04
# Total processing time: 01:02:53:18
# ----------------------------------
# Document: 2945
# Document sentence number: 87
# Optimum cluster number: 12
# Summary sentence number: 10
# Document processing time: 00:22
# Total processing time: 01:02:53:40
# ----------------------------------
# Document: 2946
# Document sentence number: 91
# Optimum cluster number: 15
# Summary sentence number: 10
# Document processing time: 00:23
# Total processing time: 01:02:54:03
# ----------------------------------
# Document: 2947
# Document sentence number: 89
# Optimum cluster number: 19
# Summary sentence number: 10
# Document processing time: 00:22
# Total processing time: 01:02:54:26
# ----------------------------------
# Document: 2948
# Document sentence number: 93
# Optimum cluster number: 19
# Summary sentence number: 10
# Document processing time: 00:24
# Total processing time: 01:02:54:51
# ----------------------------------
# Document: 2949
# Document sentence number: 77
# Optimum cluster number: 15
# Summary sentence number: 10
# Document processing time: 00:10
# Total processing time: 01:02:55:01
# ----------------------------------
# Document: 2950
# Document sentence number: 143
# Optimum cluster number: 17
# Summary sentence number: 10
# Document processing time: 00:43
# Total processing time: 01:02:55:44
# ----------------------------------
# Document: 2951
# Document sentence number: 97
# Optimum cluster number: 7
# Summary sentence number: 7
# Document processing time: 00:24
# Total processing time: 01:02:56:09
# ----------------------------------
# Document: 2952
# Document sentence number: 64
# Optimum cluster number: 9
# Summary sentence number: 9
# Document processing time: 00:07
# Total processing time: 01:02:56:16
# ----------------------------------
# Document: 2953
# Document sentence number: 217
# Optimum cluster number: 16
# Summary sentence number: 10
# Document processing time: 01:24
# Total processing time: 01:02:57:41
# ----------------------------------
# Document: 2954
# Document sentence number: 75
# Optimum cluster number: 8
# Summary sentence number: 8
# Document processing time: 00:09
# Total processing time: 01:02:57:51
# ----------------------------------
# Document: 2955
# Document sentence number: 119
# Optimum cluster number: 15
# Summary sentence number: 10
# Document processing time: 00:33
# Total processing time: 01:02:58:25
# ----------------------------------
# Document: 2956
# Document sentence number: 68
# Optimum cluster number: 8
# Summary sentence number: 8
# Document processing time: 00:08
# Total processing time: 01:02:58:33
# ----------------------------------
# Document: 2957
# Document sentence number: 42
# Optimum cluster number: 6
# Summary sentence number: 6
# Document processing time: 00:05
# Total processing time: 01:02:58:38
# ----------------------------------
# Document: 2958
# Document sentence number: 72
# Optimum cluster number: 7
# Summary sentence number: 7
# Document processing time: 00:09
# Total processing time: 01:02:58:48
# ----------------------------------
# Document: 2959
# Document sentence number: 94
# Optimum cluster number: 6
# Summary sentence number: 6
# Document processing time: 00:23
# Total processing time: 01:02:59:12
# ----------------------------------
# Document: 2960
# Document sentence number: 117
# Optimum cluster number: 28
# Summary sentence number: 10
# Document processing time: 00:34
# Total processing time: 01:02:59:46
# ----------------------------------
# Document: 2961
# Document sentence number: 102
# Optimum cluster number: 14
# Summary sentence number: 10
# Document processing time: 00:28
# Total processing time: 01:03:00:15
# ----------------------------------
# Document: 2962
# Document sentence number: 71
# Optimum cluster number: 10
# Summary sentence number: 10
# Document processing time: 00:08
# Total processing time: 01:03:00:23
# ----------------------------------
# Document: 2963
# Document sentence number: 96
# Optimum cluster number: 7
# Summary sentence number: 7
# Document processing time: 00:24
# Total processing time: 01:03:00:48
# ----------------------------------
# Document: 2964
# Document sentence number: 5
# Corpus is less than 9 sentence, summarization didn't apply sentence number: 5
# Document processing time: 00:00
# Total processing time: 01:03:00:48
# ----------------------------------
# Document: 2965
# Document sentence number: 124
# Optimum cluster number: 10
# Summary sentence number: 10
# Document processing time: 00:37
# Total processing time: 01:03:01:26
# ----------------------------------
# Document: 2966
# Document sentence number: 252
# Optimum cluster number: 11
# Summary sentence number: 10
# Document processing time: 01:44
# Total processing time: 01:03:03:10
# ----------------------------------
# Document: 2967
# Document sentence number: 74
# Optimum cluster number: 9
# Summary sentence number: 9
# Document processing time: 00:09
# Total processing time: 01:03:03:20
# ----------------------------------
# Document: 2968
# Document sentence number: 227
# Optimum cluster number: 32
# Summary sentence number: 10
# Document processing time: 01:28
# Total processing time: 01:03:04:48
# ----------------------------------
# Document: 2969
# Document sentence number: 91
# Optimum cluster number: 29
# Summary sentence number: 10
# Document processing time: 00:22
# Total processing time: 01:03:05:11
# ----------------------------------
# Document: 2970
# Document sentence number: 134
# Optimum cluster number: 18
# Summary sentence number: 10
# Document processing time: 00:39
# Total processing time: 01:03:05:50
# ----------------------------------
# Document: 2971
# Document sentence number: 109
# Optimum cluster number: 18
# Summary sentence number: 10
# Document processing time: 00:29
# Total processing time: 01:03:06:20
# ----------------------------------
# Document: 2972
# Document sentence number: 114
# Optimum cluster number: 16
# Summary sentence number: 10
# Document processing time: 00:31
# Total processing time: 01:03:06:52
# ----------------------------------
# Document: 2973
# Document sentence number: 34
# Optimum cluster number: 8
# Summary sentence number: 8
# Document processing time: 00:04
# Total processing time: 01:03:06:56
# ----------------------------------
# Document: 2974
# Document sentence number: 114
# Optimum cluster number: 30
# Summary sentence number: 10
# Document processing time: 00:34
# Total processing time: 01:03:07:30
# ----------------------------------
# Document: 2975
# Document sentence number: 187
# Optimum cluster number: 21
# Summary sentence number: 10
# Document processing time: 01:05
# Total processing time: 01:03:08:35
# ----------------------------------
# Document: 2976
# Document sentence number: 50
# Optimum cluster number: 13
# Summary sentence number: 10
# Document processing time: 00:05
# Total processing time: 01:03:08:41
# ----------------------------------
# Document: 2977
# Document sentence number: 301
# Optimum cluster number: 19
# Summary sentence number: 10
# Document processing time: 02:18
# Total processing time: 01:03:11:00
# ----------------------------------
# Document: 2978
# Document sentence number: 107
# Optimum cluster number: 27
# Summary sentence number: 10
# Document processing time: 00:28
# Total processing time: 01:03:11:28
# ----------------------------------
# Document: 2979
# Document sentence number: 85
# Optimum cluster number: 23
# Summary sentence number: 10
# Document processing time: 00:15
# Total processing time: 01:03:11:44
# ----------------------------------
# Document: 2980
# Document sentence number: 300
# Optimum cluster number: 24
# Summary sentence number: 10
# Document processing time: 02:18
# Total processing time: 01:03:14:03
# ----------------------------------
# Document: 2981
# Document sentence number: 107
# Optimum cluster number: 26
# Summary sentence number: 10
# Document processing time: 00:29
# Total processing time: 01:03:14:33
# ----------------------------------
# Document: 2982
# Document sentence number: 51
# Optimum cluster number: 11
# Summary sentence number: 10
# Document processing time: 00:06
# Total processing time: 01:03:14:39
# ----------------------------------
# Document: 2983
# Document sentence number: 40
# Optimum cluster number: 7
# Summary sentence number: 7
# Document processing time: 00:05
# Total processing time: 01:03:14:44
# ----------------------------------
# Document: 2984
# Document sentence number: 120
# Optimum cluster number: 19
# Summary sentence number: 10
# Document processing time: 00:35
# Total processing time: 01:03:15:19
# ----------------------------------
# Document: 2985
# Document sentence number: 173
# Optimum cluster number: 9
# Summary sentence number: 9
# Document processing time: 00:57
# Total processing time: 01:03:16:17
# ----------------------------------
# Document: 2986
# Document sentence number: 129
# Optimum cluster number: 10
# Summary sentence number: 10
# Document processing time: 00:38
# Total processing time: 01:03:16:56
# ----------------------------------
# Document: 2987
# Document sentence number: 118
# Optimum cluster number: 9
# Summary sentence number: 9
# Document processing time: 00:34
# Total processing time: 01:03:17:31
# ----------------------------------
# Document: 2988
# Document sentence number: 142
# Optimum cluster number: 25
# Summary sentence number: 10
# Document processing time: 00:43
# Total processing time: 01:03:18:14
# ----------------------------------
# Document: 2989
# Document sentence number: 131
# Optimum cluster number: 20
# Summary sentence number: 10
# Document processing time: 00:38
# Total processing time: 01:03:18:53
# ----------------------------------
# Document: 2990
# Document sentence number: 76
# Optimum cluster number: 19
# Summary sentence number: 10
# Document processing time: 00:09
# Total processing time: 01:03:19:03
# ----------------------------------
# Document: 2991
# Document sentence number: 72
# Optimum cluster number: 7
# Summary sentence number: 7
# Document processing time: 00:08
# Total processing time: 01:03:19:12
# ----------------------------------
# Document: 2992
# Document sentence number: 250
# Optimum cluster number: 24
# Summary sentence number: 10
# Document processing time: 01:42
# Total processing time: 01:03:20:54
# ----------------------------------
# Document: 2993
# Document sentence number: 82
# Optimum cluster number: 22
# Summary sentence number: 10
# Document processing time: 00:13
# Total processing time: 01:03:21:08
# ----------------------------------
# Document: 2994
# Document sentence number: 90
# Optimum cluster number: 6
# Summary sentence number: 6
# Document processing time: 00:22
# Total processing time: 01:03:21:31
# ----------------------------------
# Document: 2995
# Document sentence number: 44
# Optimum cluster number: 13
# Summary sentence number: 10
# Document processing time: 00:05
# Total processing time: 01:03:21:36
# ----------------------------------
# Document: 2996
# Document sentence number: 190
# Optimum cluster number: 15
# Summary sentence number: 10
# Document processing time: 01:05
# Total processing time: 01:03:22:42
# ----------------------------------
# Document: 2997
# Document sentence number: 183
# Optimum cluster number: 9
# Summary sentence number: 9
# Document processing time: 01:03
# Total processing time: 01:03:23:45
# ----------------------------------
# Document: 2998
# Document sentence number: 67
# Optimum cluster number: 18
# Summary sentence number: 10
# Document processing time: 00:07
# Total processing time: 01:03:23:53
# ----------------------------------
# Document: 2999
# Document sentence number: 99
# Optimum cluster number: 7
# Summary sentence number: 7
# Document processing time: 00:26
# Total processing time: 01:03:24:20
# ----------------------------------
# Document: 3000
# Document sentence number: 62
# Optimum cluster number: 16
# Summary sentence number: 10
# Document processing time: 00:07
# Total processing time: 01:03:24:28
# ----------------------------------

# %%
def prepare_results(m, p, r, f):
    return '\t{}:\t{}: {:5.2f}\t{}: {:5.2f}\t{}: {:5.2f}'.format(m, 'P', 100.0 * p, 'R', 100.0 * r, 'F1', 100.0 * f)

def rougeEvaluation(all_hypothesis, all_references):

    for aggregator in ['Avg']:
        print('Evaluation with {}'.format(aggregator))
        apply_avg = aggregator == 'Avg'
        apply_best = aggregator == 'Best'

        evaluator = rouge.Rouge(metrics=['rouge-n', 'rouge-l', 'rouge-w'],
                               max_n=4,
                               limit_length=False,
                               length_limit=1000,
                               length_limit_type='words',
                               apply_avg=apply_avg,
                               apply_best=apply_best,
                               alpha=0.2, # Default F1_score
                               weight_factor=1.2,
                               stemming=True)

        scores = evaluator.get_scores(all_hypothesis, all_references)

        for metric, results in sorted(scores.items(), key=lambda x: x[0]):
            if not apply_avg and not apply_best: # value is a type of list as we evaluate each summary vs each reference
                for hypothesis_id, results_per_ref in enumerate(results):
                    nb_references = len(results_per_ref['p'])
                    for reference_id in range(nb_references):
                        print('\tHypothesis #{} & Reference #{}: '.format(hypothesis_id, reference_id))
                        print('\t' + prepare_results(metric,results_per_ref['p'][reference_id], results_per_ref['r'][reference_id], results_per_ref['f'][reference_id]))
                print()
            else:
                print(prepare_results(metric, results['p'], results['r'], results['f']))
        print()

# %%
len(all_goldstandart)
# Out:
# 300

# %%
rougeEvaluation(all_summary, all_goldstandart)
# Out:
# Evaluation with Avg
# 	rouge-1:	P: 38.19	R: 50.19	F1: 45.30
# 	rouge-2:	P: 12.92	R: 16.26	F1: 14.88
# 	rouge-3:	P:  6.51	R:  7.76	F1:  7.22
# 	rouge-4:	P:  4.18	R:  4.77	F1:  4.49
# 	rouge-l:	P: 35.64	R: 44.59	F1: 41.27
# 	rouge-w:	P: 17.04	R: 11.55	F1: 11.93

# %%
# Play an audio beep. Any audio URL will do.
from google.colab import output
output.eval_js('new Audio("https://upload.wikimedia.org/wikipedia/commons/0/05/Beep-09.ogg").play()')

# %%
# Save files

import json
import os

# Define the file path
file_path = "/content/drive/Othercomputers/My Laptop/DriveAccess/GraphInClusterPubMedTextRanksavedDocumentsandSummaries-all-distilroberta-v1-Full-Pubmed-Test.json"  # Replace with the desired file path

# Check if the file already exists
if os.path.exists(file_path):
    # Read the existing data from the JSON file
    with open(file_path, "r") as file:
        existing_data = json.load(file)

    # Combine the existing data with the new data (lists)
    existing_summary = existing_data.get("all_summary", [])
    existing_goldstandart = existing_data.get("all_goldstandart", [])

    # Assuming you have three new lists: new_intermediate_summary, new_summary, new_goldstandart
    # Sample new lists (replace these with your actual lists)
    new_summary = all_summary
    new_goldstandart = all_goldstandart


    # Merge the new lists with the existing ones
    all_summary = existing_summary + new_summary
    all_goldstandart = existing_goldstandart + new_goldstandart

# Combine the lists into a dictionary for easy serialization
data = {
    "all_summary": all_summary,
    "all_goldstandart": all_goldstandart
}

# Save the data to a JSON file
with open(file_path, "w") as file:
    json.dump(data, file)

print("Lists have been saved to", file_path)
# Out:
# Lists have been saved to /content/drive/Othercomputers/My Laptop/DriveAccess/GraphInClusterPubMedTextRanksavedDocumentsandSummaries-all-distilroberta-v1-Full-Pubmed-Test.json

# %%
print(len(data['all_summary']))
# Out:
# 3000

# %%
rougeEvaluation(data['all_summary'], data['all_goldstandart'])
# Out:
# Evaluation with Avg
# 	rouge-1:	P: 37.75	R: 49.73	F1: 44.80
# 	rouge-2:	P: 12.65	R: 16.16	F1: 14.65
# 	rouge-3:	P:  6.15	R:  7.52	F1:  6.88
# 	rouge-4:	P:  3.80	R:  4.47	F1:  4.12
# 	rouge-l:	P: 35.22	R: 44.15	F1: 40.78
# 	rouge-w:	P: 16.79	R: 11.44	F1: 11.78

# %%
# Play an audio beep. Any audio URL will do.
from google.colab import output
output.eval_js('new Audio("https://upload.wikimedia.org/wikipedia/commons/0/05/Beep-09.ogg").play()')

# %%
sentencenumber=0
for i in range(len(all_summary)):
  sentencenumber=sentencenumber+textSentenceCount(all_summary[i])

avg=sentencenumber/len(all_summary)
avg
# Out:
# 8.779333333333334

# %%
sentencenumber=0
for i in range(len(all_goldstandart)):
  sentencenumber=sentencenumber+textSentenceCount(all_goldstandart[i])

avg=sentencenumber/len(all_goldstandart)
avg
# Out:
# 7.605666666666667
